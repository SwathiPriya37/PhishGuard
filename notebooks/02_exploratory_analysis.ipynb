# %% [markdown]
# # 02_exploratory_analysis.ipynb

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Load cleaned dataset

# %%
df = pd.read_csv("../data/cleaned_data.csv")
df.head()
# Out:
#                                        text_combined  label  \
# 0  hpl nom may 25 2001 see attached file hplno 52...      0
# 1  nom actual vols 24 th forwarded sabrae zajac h...      0
# 2  enron actuals march 30 april 1 201 estimated a...      0
# 3  hpl nom may 30 2001 see attached file hplno 53...      0
# 4  hpl nom june 1 2001 see attached file hplno 60...      0
#
#                                           clean_text
# 0  hpl nom may see attached file hplno xls hplno xls
# 1  nom actual vols th forwarded sabrae zajac hou ...
# 2  enron actuals march april estimated actuals ma...
# 3  hpl nom may see attached file hplno xls hplno xls
# 4  hpl nom june see attached file hplno xls hplno...

# %% [markdown]
# Label distribution

# %%
plt.figure(figsize=(6,4))
sns.countplot(x="label", data=df, palette="Set2")
plt.title("Class Distribution")
plt.xlabel("Label")
plt.ylabel("Count")
plt.show()
# Out:
# C:\Users\Swathi priya\AppData\Local\Temp\ipykernel_1128\4240716135.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x="label", data=df, palette="Set2")

# %% [markdown]
# Text length distribution

# %%
df["clean_text"] = df["clean_text"].fillna("").astype(str)
df["text_len"] = df["clean_text"].apply(len)

plt.figure(figsize=(8,5))
sns.histplot(df["text_len"], bins=50, kde=True, color="blue")
plt.title("Text Length Distribution")
plt.xlabel("Text Length")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# Convert to dataframe for plotting

# %%
from collections import Counter

# Get the 20 most common words and their counts
common_words = Counter(words).most_common(20)

common_words_df = pd.DataFrame(common_words, columns=["word", "count"])

# %% [markdown]
# Plot bar chart of top 20 most frequent words

# %%
plt.figure(figsize=(10,6))
sns.barplot(x="count", y="word", data=common_words_df, palette="viridis")
plt.title("Top 20 Most Frequent Words")
plt.xlabel("Count")
plt.ylabel("Word")
plt.show()
# Out:
# C:\Users\Swathi priya\AppData\Local\Temp\ipykernel_1128\6377712.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="count", y="word", data=common_words_df, palette="viridis")
